# %% [markdown]
# <a href="https://colab.research.google.com/github/DerinOgrenme2021/GizemUnal/blob/main/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X,y=load_iris(return_X_y=True)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
gnb=GaussianNB()
gnb.fit(X_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_predict = gnb.predict(X_test)
y_predict
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 1, 2, 1, 1, 1, 0, 0, 1, 0, 0, 2, 1, 1, 2, 1,
#        0, 0, 0, 0, 2, 2, 2, 2])

# %%
y_test
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 1, 2, 2, 1, 1, 0, 0, 1, 0, 0, 2, 1, 1, 2, 1,
#        0, 0, 0, 0, 2, 1, 2, 2])

# %%
from sklearn.metrics import accuracy_score,precision_score

accuracy_score(y_test,y_predict)
precision_score(y_test,y_predict, average=None)
# Out:
# array([1.        , 0.90909091, 0.85714286])

# %%
from sklearn import tree
dtc = tree.DecisionTreeClassifier()
dtc.fit(X_train,y_train)
y_predict= dtc.predict(X_test)

# %%
y_predict
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 1, 2, 2, 1, 1, 0, 0, 2, 0, 0, 2, 1, 1, 2, 1,
#        0, 0, 0, 0, 2, 2, 2, 2])

# %%
y_test
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 1, 2, 2, 1, 1, 0, 0, 1, 0, 0, 2, 1, 1, 2, 1,
#        0, 0, 0, 0, 2, 1, 2, 2])

# %%
from sklearn.metrics import accuracy_score,precision_score

accuracy_score(y_test,y_predict)
precision_score(y_test,y_predict, average=None)
# Out:
# array([1.        , 1.        , 0.77777778])

# %%
from sklearn.neighbors import NearestCentroid
nn=NearestCentroid()
nn.fit(X_train,y_train)
y_predict= nn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score

accuracy_score(y_test,y_predict)
#precision_score(y_test,y_predict, average=None)
# Out:
# 0.8333333333333334

# %%
y_predict
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 1, 2, 1, 1, 1, 0, 0, 1, 0, 0, 2, 1, 1, 1, 1,
#        0, 0, 0, 0, 2, 2, 1, 1])

# %%
y_test
# Out:
# array([1, 0, 1, 0, 0, 0, 1, 1, 2, 2, 1, 1, 0, 0, 1, 0, 0, 2, 1, 1, 2, 1,
#        0, 0, 0, 0, 2, 1, 2, 2])

# %%
from sklearn.neural_network import MLPClassifier
mlp=MLPClassifier()
mlp.fit(X_train,y_train)
y_predict= mlp.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
from sklearn.metrics import accuracy_score,precision_score

accuracy_score(y_test,y_predict)
#precision_score(y_test,y_predict, average=None)
# Out:
# 0.9333333333333333
