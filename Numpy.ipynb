# %% [markdown]
# <a href="https://colab.research.google.com/github/DerinOgrenme2021/GizemUnal/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "http://vis-www.cs.umass.edu/lfw/lfw.tgz"
# Out:
# --2021-04-19 18:47:07--  http://vis-www.cs.umass.edu/lfw/lfw.tgz
# Resolving vis-www.cs.umass.edu (vis-www.cs.umass.edu)... 128.119.244.95
# Connecting to vis-www.cs.umass.edu (vis-www.cs.umass.edu)|128.119.244.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 180566744 (172M) [application/x-gzip]
# Saving to: ‘lfw.tgz’
#
# lfw.tgz             100%[===================>] 172.20M  35.5MB/s    in 5.3s
#
# 2021-04-19 18:47:12 (32.2 MB/s) - ‘lfw.tgz’ saved [180566744/180566744]

# %%
# !tar xvzf lfw.tgz

# %%
import numpy as np
from skimage.io import imread_collection


image_list = imread_collection("lfw/*/*.jpg")[:150]


images_average=np.zeros([250,250,3])

for img in image_list:
 images_average=images_average+img/100

skimage.io.imsave("new_image.jpg",images_average)
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [69.63, 301.72999999999996]. Convert image to uint8 prior to saving to suppress this warning.
